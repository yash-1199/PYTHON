# %% [markdown]
# **A module is a simple python file(.py) that contains**
# - functions
# - variables
# > we will have clear code

# %%
import math
print(math.sqrt(5))
# Out:
# 2.23606797749979

# %%
from math import *
sqrt(25)
# Out:
# 5.0
