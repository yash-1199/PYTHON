# %% [markdown]
# append()

# %%
my_list=[55,65,78,58]

print(dir(my_list))

print(help(list.index))

# %%
my_list=[55,65,78,58,78,86]
my_list.reverse()
print(my_list)

# %%
print(help(list.sort))

# %%
my_list=[55,65,78,58,78,86]
my_list.sort(reverse=False)
print(my_list)

# %%
my_list=[55,65,78,58,78,86]
my_list.pop()
print(help(list.pop))

# %%
my_list=[55,65,78,58,78,86]
my_list.index(78,3,5)

# %%
num=[2,3,5,8]
num.append(10)
num.insert(8,100)
print(num)

# %% [markdown]
# These are methods used by python internaly
# l=[45,55,65]
# l[2]=l.__getitem__(2)
# len(l)=>l.__len__

# %%
l=['Rahul','Sita','Ram']
l.clear()
print(l)

# %%
print(help(list.clear))

# %%
l=[85,52,85]
l1=l.copy()
print(l1)
print(id(l))
print(id(l1))

# %% [markdown]
# - Shallow copy → copies references of inner objects
# - Deep copy → copies actual inner objects

# %%
l=l1
print(id(l))
print(id(l1))

# %%
a=[1,2,3]
b=a
print('memory location of a   ',id(a))
print('memory location of b   ',id(b))

# %%
c=[1,2,3]
d=c.copy()
print('memory location of c   ',id(c))
print('memory location of d   ',id(d))

# %% [markdown]
# 10GB-textfile--t
# 11GB-hard disk space
#
# p=t.copy()
# p=t

# %%
a=[1,2,3,2]
print(a.count(4))
#print(help(list.count))

# %%
l1=[55,65,85]
l2=[12,52]
l1.extend(l2)
print(l1)
l1.extend([54,1])
print(l1)

print(l1+l2)

# %%
ll1=[2,3]
print(id(ll1))
ll2=[3,4]
ll1=ll1+ll2

# %%
print(id(ll1))

# %%
ll1.extend(ll2)
print(id(ll1))

# %%
#shallow copy
#  & deep copy
