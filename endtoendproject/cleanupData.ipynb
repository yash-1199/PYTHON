# %%
spark.conf.set('fs.azure.account.key.janbatchsa.dfs.core.windows.net', '/8EpJrGVnWWqCWRQZJoF9XW4XGNA/OqgLybXpnsTzMD8oGHRfaYCG/CHNWAdUORPtI1hX3d9VIor+AStP4q1lw==')

# %%
path='abfss://raw@janbatchsa.dfs.core.windows.net/data.json'

# %%
raw_df=spark.read.format('json').load(path)
raw_df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8184542367696851>, line 2
#       1 raw_df=spark.read.format('json').load(path)
# ----> 2 raw_df.show()
#
# File /databricks/spark/python/pyspark/sql/connect/dataframe.py:1156, in DataFrame.show(self, n, truncate, vertical)
#    1155 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1156     print(self._show_string(n, truncate, vertical))
#
# File /databricks/spark/python/pyspark/sql/connect/dataframe.py:909, in DataFrame._show_string(self, n, truncate, vertical)
#     892     except ValueError:
#     893         raise PySparkTypeError(
#     894             errorClass="NOT_BOOL",
#     895             messageParameters={
#    (...)
#     898             },
#     899         )
#     901 table, _ = DataFrame(
#     902     plan.ShowString(
# ...

# %%
raw_df.printSchema()

# %%
from pyspark.sql.functions import *
df_silver=raw_df.select(col('id').cast('int').alias('user_id'),col('name').alias('user_name'),col('email'),col('cNmae').alias('Company_Name'))
display(df_silver)

# %%
path_silver='abfss://silver@janbatchsa.dfs.core.windows.net/cleaned_data'

# %%
df_silver.write.mode('overwrite').format('delta').save(path_silver)

# %%
silver_df=spark.read.format('delta').load(path_silver)
silver_df.show()
